# %%
import pandas as pd
df = pd.read_csv('../Data/Cleaned_data.csv')
df['CoGender'].value_counts()
# Out:
# CoGender
# 2    335302
# 4    269075
# 1     61107
# 3     15383
# Name: count, dtype: int64

# %%
df = df[df['CoGender'] != 3]
df = df[df['CoGender'] != 4]
min_count = df['CoGender'].value_counts().min()
df = df.groupby('CoGender').sample(n=min_count, random_state=42)
df = df.reset_index(drop=True)
df['CoGender'].value_counts()
# Out:
# CoGender
# 1    61107
# 2    61107
# Name: count, dtype: int64

# %%
import os
import time
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
from sklearn.dummy import DummyClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.linear_model import SGDClassifier, LogisticRegression
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC


results_dir = "CoGender_SPLITS"
os.makedirs(results_dir, exist_ok=True)
# df = pd.read_csv("'../Data/Sampled_data.csv'")

X = df.drop(columns=["CoGender","BoGender"])
y = df["CoGender"]

splits = [(0.90, 0.10), (0.80, 0.20), (0.70, 0.30), (0.50, 0.50)]

models = {
    "ZeroR": DummyClassifier(strategy="most_frequent"),
    "SGD Classifier": SGDClassifier(loss="log_loss", max_iter=1000, tol=1e-3, random_state=42),
    "Random Forest": RandomForestClassifier(n_estimators=100, random_state=42),
    "Decision Tree": DecisionTreeClassifier(random_state=42),
    # "Logistic Regression": LogisticRegression(
    #     max_iter=1000, 
    #     random_state=42, 
    #     multi_class="multinomial",  # Ensures proper handling of multi-class classification
    #     solver="lbfgs"  # Use "saga" for large datasets
    #     ),
    "Extra Trees": ExtraTreesClassifier(n_estimators=100, random_state=42),
    "Gradient Boosting": GradientBoostingClassifier(n_estimators=100, random_state=42), 
    "KNN": KNeighborsClassifier(n_neighbors=2),
    # "Support Vector Machine": SVC(kernel="rbf", probability=True, random_state=42),  
}

def specificity_score(y_true, y_pred):
    cm = confusion_matrix(y_true, y_pred)
    tn = np.sum(cm) - np.sum(cm, axis=0) - np.sum(cm, axis=1) + np.diag(cm)  # True Negatives per class
    fp = np.sum(cm, axis=0) - np.diag(cm)  # False Positives per class
    specificity_per_class = tn / (tn + fp)  # Compute specificity per class
    return np.mean(specificity_per_class)  # Return the average specificity

for train_size, test_size in splits:
    train_percent = int(train_size * 100)
    test_percent = int(test_size * 100)

    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=42)
    
    print(f"\nTraining/Testing Split: {train_percent}%/{test_percent}%\n")
    
    results = {}
    conf_matrices = {}
    
    for name, model in models.items():
        start_time = time.time()
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)
        
        acc = accuracy_score(y_test, y_pred)
        prec = precision_score(y_test, y_pred, average='macro', zero_division=1)
        rec = recall_score(y_test, y_pred, average='macro')
        f1 = f1_score(y_test, y_pred, average='macro')
        spec = specificity_score(y_test, y_pred)
        cm = confusion_matrix(y_test, y_pred)
        elapsed_time = time.time() - start_time
        
        results[name] = {
            "Accuracy": acc, 
            "Precision": prec, 
            "Recall": rec, 
            "F1-Score": f1, 
            "Specificity": spec,
            "Total Runtime (s)": elapsed_time,
        }
        conf_matrices[name] = cm
        print(f"Model: {name}\n Accuracy: {acc:.4f}, Precision: {prec:.4f}, Recall: {rec:.4f}, F1-Score: {f1:.4f}, Specificity: {spec:.4f}")
        print("Time taken: {:.2f} seconds\n".format(elapsed_time))
        
    results_df = pd.DataFrame(results).T
    results_file = f"{results_dir}/results_split_{train_percent}_{test_percent}.csv"
    results_df.to_csv(results_file, index=True)
    print(f"Results saved to {results_file}")

    for name, cm in conf_matrices.items():
        cm_file = f"{results_dir}/conf_matrix_{train_percent}_{test_percent}_{name.replace(' ', '_')}.csv"
        pd.DataFrame(cm).to_csv(cm_file, index=False)
        print(f"Confusion Matrix for {name} saved to {cm_file}")
    
    fig, axes = plt.subplots(2, 4, figsize=(24, 12))
    axes = axes.ravel()
    
    for i, (name, cm) in enumerate(conf_matrices.items()):
        sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', ax=axes[i])
        axes[i].set_title(f'Confusion Matrix - {name} ({train_percent}%/{test_percent}%)')
        axes[i].set_xlabel('Predicted Label')
        axes[i].set_ylabel('True Label')
    
    plt.tight_layout()
    plt.show()
# Out:
# Training/Testing Split: 90%/10%
#
# Model: ZeroR
#  Accuracy: 0.4901, Precision: 0.7450, Recall: 0.5000, F1-Score: 0.3289, Specificity: 0.5000
# Time taken: 0.01 seconds
#
# Model: SGD Classifier
#  Accuracy: 0.5298, Precision: 0.5759, Recall: 0.5369, F1-Score: 0.4647, Specificity: 0.5369
# Time taken: 3.63 seconds
#
# Model: Random Forest
#  Accuracy: 0.9591, Precision: 0.9594, Recall: 0.9595, F1-Score: 0.9591, Specificity: 0.9595
# Time taken: 19.71 seconds
#
# Model: Decision Tree
#  Accuracy: 0.9209, Precision: 0.9210, Recall: 0.9207, F1-Score: 0.9208, Specificity: 0.9207
# Time taken: 2.18 seconds
#
# Model: Extra Trees
#  Accuracy: 0.9581, Precision: 0.9585, Recall: 0.9585, F1-Score: 0.9581, Specificity: 0.9585
# Time taken: 6.79 seconds
#
# Model: Gradient Boosting
#  Accuracy: 0.9591, Precision: 0.9595, Recall: 0.9595, F1-Score: 0.9591, Specificity: 0.9595
# Time taken: 23.70 seconds
#
# Model: KNN
#  Accuracy: 0.5295, Precision: 0.5314, Recall: 0.5250, F1-Score: 0.5018, Specificity: 0.5250
# Time taken: 0.75 seconds
#
# Results saved to CoGender_SPLITS/results_split_90_10.csv
# Confusion Matrix for ZeroR saved to CoGender_SPLITS/conf_matrix_90_10_ZeroR.csv
# Confusion Matrix for SGD Classifier saved to CoGender_SPLITS/conf_matrix_90_10_SGD_Classifier.csv
# Confusion Matrix for Random Forest saved to CoGender_SPLITS/conf_matrix_90_10_Random_Forest.csv
# Confusion Matrix for Decision Tree saved to CoGender_SPLITS/conf_matrix_90_10_Decision_Tree.csv
# Confusion Matrix for Extra Trees saved to CoGender_SPLITS/conf_matrix_90_10_Extra_Trees.csv
# Confusion Matrix for Gradient Boosting saved to CoGender_SPLITS/conf_matrix_90_10_Gradient_Boosting.csv
# Confusion Matrix for KNN saved to CoGender_SPLITS/conf_matrix_90_10_KNN.csv
# Training/Testing Split: 80%/20%
#
# Model: ZeroR
#  Accuracy: 0.4938, Precision: 0.7469, Recall: 0.5000, F1-Score: 0.3305, Specificity: 0.5000
# Time taken: 0.02 seconds
#
# Model: SGD Classifier
#  Accuracy: 0.5251, Precision: 0.5554, Recall: 0.5201, F1-Score: 0.4317, Specificity: 0.5201
# Time taken: 2.95 seconds
#
# Model: Random Forest
#  Accuracy: 0.9577, Precision: 0.9584, Recall: 0.9580, F1-Score: 0.9577, Specificity: 0.9580
# Time taken: 17.13 seconds
#
# Model: Decision Tree
#  Accuracy: 0.9211, Precision: 0.9211, Recall: 0.9211, F1-Score: 0.9211, Specificity: 0.9211
# Time taken: 1.94 seconds
#
# Model: Extra Trees
#  Accuracy: 0.9557, Precision: 0.9566, Recall: 0.9560, F1-Score: 0.9557, Specificity: 0.9560
# Time taken: 6.16 seconds
#
# Model: Gradient Boosting
#  Accuracy: 0.9588, Precision: 0.9595, Recall: 0.9590, F1-Score: 0.9588, Specificity: 0.9590
# Time taken: 21.20 seconds
#
# Model: KNN
#  Accuracy: 0.5344, Precision: 0.5402, Recall: 0.5315, F1-Score: 0.5061, Specificity: 0.5315
# Time taken: 1.02 seconds
#
# Results saved to CoGender_SPLITS/results_split_80_20.csv
# Confusion Matrix for ZeroR saved to CoGender_SPLITS/conf_matrix_80_20_ZeroR.csv
# Confusion Matrix for SGD Classifier saved to CoGender_SPLITS/conf_matrix_80_20_SGD_Classifier.csv
# Confusion Matrix for Random Forest saved to CoGender_SPLITS/conf_matrix_80_20_Random_Forest.csv
# Confusion Matrix for Decision Tree saved to CoGender_SPLITS/conf_matrix_80_20_Decision_Tree.csv
# Confusion Matrix for Extra Trees saved to CoGender_SPLITS/conf_matrix_80_20_Extra_Trees.csv
# Confusion Matrix for Gradient Boosting saved to CoGender_SPLITS/conf_matrix_80_20_Gradient_Boosting.csv
# Confusion Matrix for KNN saved to CoGender_SPLITS/conf_matrix_80_20_KNN.csv
# Training/Testing Split: 70%/30%
#
# Model: ZeroR
#  Accuracy: 0.4973, Precision: 0.7486, Recall: 0.5000, F1-Score: 0.3321, Specificity: 0.5000
# Time taken: 0.02 seconds
#
# Model: SGD Classifier
#  Accuracy: 0.5092, Precision: 0.5597, Recall: 0.5066, F1-Score: 0.3669, Specificity: 0.5066
# Time taken: 2.20 seconds
#
# Model: Random Forest
#  Accuracy: 0.9574, Precision: 0.9583, Recall: 0.9576, F1-Score: 0.9574, Specificity: 0.9576
# Time taken: 14.80 seconds
#
# Model: Decision Tree
#  Accuracy: 0.9217, Precision: 0.9218, Recall: 0.9217, F1-Score: 0.9217, Specificity: 0.9217
# Time taken: 1.76 seconds
#
# Model: Extra Trees
#  Accuracy: 0.9562, Precision: 0.9571, Recall: 0.9563, F1-Score: 0.9562, Specificity: 0.9563
# Time taken: 5.19 seconds
#
# Model: Gradient Boosting
#  Accuracy: 0.9584, Precision: 0.9593, Recall: 0.9585, F1-Score: 0.9584, Specificity: 0.9585
# Time taken: 18.37 seconds
#
# Model: KNN
#  Accuracy: 0.5297, Precision: 0.5362, Recall: 0.5284, F1-Score: 0.5023, Specificity: 0.5284
# Time taken: 1.39 seconds
#
# Results saved to CoGender_SPLITS/results_split_70_30.csv
# Confusion Matrix for ZeroR saved to CoGender_SPLITS/conf_matrix_70_30_ZeroR.csv
# Confusion Matrix for SGD Classifier saved to CoGender_SPLITS/conf_matrix_70_30_SGD_Classifier.csv
# Confusion Matrix for Random Forest saved to CoGender_SPLITS/conf_matrix_70_30_Random_Forest.csv
# Confusion Matrix for Decision Tree saved to CoGender_SPLITS/conf_matrix_70_30_Decision_Tree.csv
# Confusion Matrix for Extra Trees saved to CoGender_SPLITS/conf_matrix_70_30_Extra_Trees.csv
# Confusion Matrix for Gradient Boosting saved to CoGender_SPLITS/conf_matrix_70_30_Gradient_Boosting.csv
# Confusion Matrix for KNN saved to CoGender_SPLITS/conf_matrix_70_30_KNN.csv
# Training/Testing Split: 50%/50%
#
# Model: ZeroR
#  Accuracy: 0.4987, Precision: 0.7493, Recall: 0.5000, F1-Score: 0.3328, Specificity: 0.5000
# Time taken: 0.03 seconds
#
# Model: SGD Classifier
#  Accuracy: 0.5121, Precision: 0.5716, Recall: 0.5109, F1-Score: 0.3799, Specificity: 0.5109
# Time taken: 0.52 seconds
#
# Model: Random Forest
#  Accuracy: 0.9569, Precision: 0.9579, Recall: 0.9570, F1-Score: 0.9569, Specificity: 0.9570
# Time taken: 10.50 seconds
#
# Model: Decision Tree
#  Accuracy: 0.9211, Precision: 0.9211, Recall: 0.9211, F1-Score: 0.9211, Specificity: 0.9211
# Time taken: 1.22 seconds
#
# Model: Extra Trees
#  Accuracy: 0.9556, Precision: 0.9566, Recall: 0.9556, F1-Score: 0.9555, Specificity: 0.9556
# Time taken: 3.83 seconds
#
# Model: Gradient Boosting
#  Accuracy: 0.9582, Precision: 0.9592, Recall: 0.9583, F1-Score: 0.9582, Specificity: 0.9583
# Time taken: 13.93 seconds
#
# Model: KNN
#  Accuracy: 0.5264, Precision: 0.5328, Recall: 0.5258, F1-Score: 0.4995, Specificity: 0.5258
# Time taken: 2.27 seconds
#
# Results saved to CoGender_SPLITS/results_split_50_50.csv
# Confusion Matrix for ZeroR saved to CoGender_SPLITS/conf_matrix_50_50_ZeroR.csv
# Confusion Matrix for SGD Classifier saved to CoGender_SPLITS/conf_matrix_50_50_SGD_Classifier.csv
# Confusion Matrix for Random Forest saved to CoGender_SPLITS/conf_matrix_50_50_Random_Forest.csv
# Confusion Matrix for Decision Tree saved to CoGender_SPLITS/conf_matrix_50_50_Decision_Tree.csv
# Confusion Matrix for Extra Trees saved to CoGender_SPLITS/conf_matrix_50_50_Extra_Trees.csv
# Confusion Matrix for Gradient Boosting saved to CoGender_SPLITS/conf_matrix_50_50_Gradient_Boosting.csv
# Confusion Matrix for KNN saved to CoGender_SPLITS/conf_matrix_50_50_KNN.csv

# %%
import os
import time
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import cross_val_predict, StratifiedKFold
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
from sklearn.dummy import DummyClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier

# Create results directory if not exists
cv_results_dir = "cv_results"
os.makedirs(cv_results_dir, exist_ok=True)

# Load the dataset
df = pd.read_csv("merged_data_step_3_sampled_v2.csv", low_memory=False) 

# Define features and target
X = df.drop(columns=["Borrower Credit Score"])
y = df["Borrower Credit Score"]

# Define models
models = {
    "ZeroR": DummyClassifier(strategy="most_frequent"),
    "Random Forest": RandomForestClassifier(n_estimators=100, random_state=42),
    "Decision Tree": DecisionTreeClassifier(random_state=42),
    "Extra Trees": ExtraTreesClassifier(n_estimators=100, random_state=42),
    # "Logistic Regression": LogisticRegression(max_iter=1000, random_state=42),
    # "Gradient Boosting": GradientBoostingClassifier(n_estimators=100, random_state=42),
    # "KNN": KNeighborsClassifier(n_neighbors=5),
}

# Function to calculate specificity
def specificity_score(y_true, y_pred):
    cm = confusion_matrix(y_true, y_pred)
    tn = np.sum(cm) - np.sum(cm, axis=0) - np.sum(cm, axis=1) + np.diag(cm)  # True Negatives per class
    fp = np.sum(cm, axis=0) - np.diag(cm)  # False Positives per class
    specificity_per_class = tn / (tn + fp)  # Compute specificity per class
    return np.mean(specificity_per_class)  # Return the average specificity

# Define number of folds for cross-validation
folds_list = [5, 10, 20]

# Iterate over each number of folds
for num_folds in folds_list:
    print(f"\nPerforming {num_folds}-fold cross-validation\n")
    kf = StratifiedKFold(n_splits=num_folds, shuffle=True, random_state=42)
    
    results = {}
    conf_matrices = {}
    
    for name, model in models.items():
        start_time = time.time()
        y_pred = cross_val_predict(model, X, y, cv=kf)
        total_runtime = time.time() - start_time  # End timing
        
        acc = accuracy_score(y, y_pred)
        prec = precision_score(y, y_pred, average='weighted', zero_division=1)
        rec = recall_score(y, y_pred, average='weighted')
        f1 = f1_score(y, y_pred, average='weighted')
        spec = specificity_score(y, y_pred)
        cm = confusion_matrix(y, y_pred)
        
        results[name] = {
            "Accuracy": acc, "Precision": prec, "Recall": rec, "F1-Score": f1,
            "Specificity": spec, "Total Runtime (s)": total_runtime, "Total Runtime (min)": total_runtime / 60
        }
        
        conf_matrices[name] = cm
        
        print(f"Model: {name}\n Accuracy: {acc:.4f}, Precision: {prec:.4f}, Recall: {rec:.4f}, F1-Score: {f1:.4f}, Specificity: {spec:.4f}")
        print("Time taken: {:.2f} seconds".format(total_runtime))
        print("Time taken: {:.2f} minutes\n".format(total_runtime / 60))
    
    # Convert results to DataFrame and save to CSV
    results_df = pd.DataFrame(results).T
    results_file = f"{cv_results_dir}/results_cv_{num_folds}_folds.csv"
    results_df.to_csv(results_file, index=True)
    print(f"Results saved to {results_file}")

    # Save confusion matrices
    for name, cm in conf_matrices.items():
        cm_file = f"{cv_results_dir}/conf_matrix_cv_{num_folds}_folds_{name.replace(' ', '_')}.csv"
        pd.DataFrame(cm).to_csv(cm_file, index=False)
        print(f"Confusion Matrix for {name} saved to {cm_file}")
    
    # Plot confusion matrices
    fig, axes = plt.subplots(2, 4, figsize=(24, 12))
    axes = axes.ravel()
    
    for i, (name, cm) in enumerate(conf_matrices.items()):
        sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', ax=axes[i])
        axes[i].set_title(f'Confusion Matrix - {name} ({num_folds}-Folds CV)')
        axes[i].set_xlabel('Predicted Label')
        axes[i].set_ylabel('True Label')
    
    plt.tight_layout()
    plt.show()
